# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaNarayan0613/DivyaNarayan0613/blob/main/Latest_Leukemia_Train_and_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # import zipfile - ZipFile is a class of zipfile module for reading and writing zip files. Here we import only class ZipFile from zipfile module. with ZipFile(file_name, 'r') as zip: Here, a ZipFile object is made by calling ZipFile constructor which accepts zip file name and mode parameters

# %% [markdown]
# # import os - The OS module in Python provides functions for creating and removing a directory (folder), fetching its contents, changing and identifying the current directory, etc.
#
# # import the os module to interact with the underlying operating system.

# %%
import os
import zipfile

# %%
from zipfile import ZipFile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Once all the contents in the zipfile is extracted close the archive file. You must call close() before exiting your program or essential records will not be written.

# %%
zip_ref=zipfile.ZipFile('/content/drive/MyDrive/PKG - C-NMC_Leukemia.zip', 'r') #Opens the zip file in read mode
zip_ref.extractall('Project') #Extracts the files into the /tmp folder
zip_ref.close()

# %% [markdown]
# # os.listdir() method in python is used to get the list of all files and directories in the specified directory.

# %%
os.listdir('/content/Project')
# Out:
# ['PKG - C-NMC_Leukemia']

# %%
len(os.listdir('/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data'))
# Out:
# 3

# %%
len(os.listdir('/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_test_prelim_phase_data'))
# Out:
# 1868

# %%
len(os.listdir('/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_test_final_phase_data'))
# Out:
# 2586

# %%
test_data = r'/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_test_prelim_phase_data'

# %% [markdown]
# # matplotlib.pyplot is a collection of command style functions that make matplotlib work like MATLAB. Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc. In matplotlib.pyplot various states are preserved across function calls, so that it keeps track of things like the current figure and plotting area, and the plotting functions are directed to the current axes

# %%
import matplotlib.pyplot as plt
leu = os.listdir("/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data/fold_0/all")
leu_dir = "/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data/fold_0/all"

plt.figure(figsize=(20, 10))

for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(os.path.join(leu_dir,leu[i]))
    plt.imshow(img, cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %%
import matplotlib.pyplot as plt
nor = os.listdir("/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data/fold_1/hem")
nor_dir = "/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data/fold_1/hem"

plt.figure(figsize=(20, 10))

for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(os.path.join(leu_dir,leu[i]))
    plt.imshow(img, cmap='gray')
    plt.axis('off')

plt.tight_layout()

# %% [markdown]
# # pandas is a Python package that provides fast, flexible, and expressive data structures designed to make working with "relational" or "labeled" data both easy and intuitive. It aims to be the fundamental high-level building block for doing practical, real world data analysis in Python. Additionally, it has the broader goal of becoming the most powerful and flexible open source data analysis / manipulation tool available in any language.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import imageio
import os, shutil
import tensorflow as tf

# %% [markdown]
# # Cancer Cell Images

# %%
fold0_all = r'/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data/fold_0/all'
fold1_all = r'/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data/fold_1/all'
fold2_all = r'/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data/fold_2/all'

# %% [markdown]
# # Normal Cell Images

# %%
fold0_hem = r'/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data/fold_0/hem'
fold1_hem = r'/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data/fold_1/hem'
fold2_hem = r'/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_training_data/fold_2/hem'

# %% [markdown]
# # Test Data

# %%
test_labels =pd.read_csv('/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_test_prelim_phase_data/C-NMC_test_prelim_phase_data_labels.csv')

# %% [markdown]
# # These lines of codes display how an Acute Lymphoblastic Leukemia (ALL) looks like

# %%
#blood cell with Acute lymphoblastic leukemia
can_image_fnames = os.listdir(fold0_all)
cancer_img = imageio.imread(os.path.join(fold0_all,
                                         can_image_fnames[5]))
plt.imshow(cancer_img)
plt.show()
# Out:
# <ipython-input-16-278bbf6f2373>:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   cancer_img = imageio.imread(os.path.join(fold0_all,

# %% [markdown]
# # These lines of code display how a healthy cell looks like

# %%
#blood cell without cancer
nrml_image_fnames = os.listdir(fold0_hem)
cell_img = imageio.imread(os.path.join(fold0_hem,
                                         nrml_image_fnames[5]))

plt.imshow(cell_img)
plt.show()
# Out:
# <ipython-input-17-14aead66a328>:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   cell_img = imageio.imread(os.path.join(fold0_hem,

# %% [markdown]
# # To see the dimensions of each and every image used here in the dataset.

# %%
cell_img.shape
#image is 450x450 pxls with color
# Out:
# (450, 450, 3)

# %% [markdown]
# # The function given below is to fetch each and every image used for the training and testing of the classification model

# %%
def get_path_image(folder):
    image_paths = []
    image_fnames = os.listdir(folder)
    for img_id in range(len(image_fnames)):
        img = os.path.join(folder,image_fnames[img_id])
        image_paths.append(img)

    return image_paths

# %% [markdown]
# # The actual path of all the cancer cell images in the dataset

# %%
#image absolute paths for cancer cells
x_col = []

for i in [fold0_all,fold1_all,fold2_all]:
    paths = get_path_image(i)
    x_col.extend(paths)
print(len(x_col))
# Out:
# 7272

# %% [markdown]
# # The actual path of all the healthy cell images in the dataset

# %%
#image absolute paths for normal cells
for i in [fold0_hem,fold1_hem,fold2_hem]:
    paths = get_path_image(i)
    x_col.extend(paths)
print(len(x_col))
# Out:
# 10661

# %% [markdown]
# # Given an image, presence of cancer is labelled as '1' and a healthy cell is labelled as '0'
# # So our 'x' is the image and the corresponding predicted 'y' is to be predicted as '0' or '1' accordingly

# %% [markdown]
# # So, the given 'x' and 'y' is convereted into a dataframe (into rows and columns).

# %%
canxr = {"x_col":x_col,
         "y_col":[np.nan for x in range(len(x_col))]}

# %% [markdown]
# # The converted dataframe is convereted to training dataset

# %%
train_df = pd.DataFrame(canxr)

# %% [markdown]
# # In column y, from row 0 to row 7271, the images are related to Acute Lymphoblastic Leukemia (ALL) and from row 7272 till the last row, the images are healthy blood cells

# %%
train_df["y_col"][0:7272] = "ALL"
train_df["y_col"][7272:10662] = "HEM"
# Out:
# <ipython-input-24-db95f7a952bc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_df["y_col"][0:7272] = "ALL"
# <ipython-input-24-db95f7a952bc>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'ALL' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   train_df["y_col"][0:7272] = "ALL"

# %%
train_df["y_col"][7271:7280]
# Out:
# 7271    ALL
# 7272    HEM
# 7273    HEM
# 7274    HEM
# 7275    HEM
# 7276    HEM
# 7277    HEM
# 7278    HEM
# 7279    HEM
# Name: y_col, dtype: object

# %% [markdown]
# # We are finding the class imbalance in the dataset. Out  of the entire training data 68% of the data belongs to cancer and remaining 32% belongs to healthy blood cells.

# %%
plt.pie([len(train_df[train_df["y_col"]=="ALL"]),len(train_df[train_df["y_col"]=="HEM"])],
        labels=["ALL","HEM"],autopct='%.f'
       )
plt.gca()
plt.show()

# %% [markdown]
# # Validating the machine learning model outputs are important to ensure its accuracy. When a machine learning model is trained, a huge amount of training data is used and the main aim of checking the model validation provides an opportunity for machine learning engineers to improve the data quality and quantity.
# # The validation set is used for hyperparameter tuning. The test set is used for the final evaluation of the best model. The validation set is not needed (redundant) if you're not going to perform hyperparameter tuning

# %% [markdown]
# # Test Data Preparation

# %%
test_x = get_path_image(test_data)

# %%
len(test_x)
# Out:
# 1868

# %%
test_labels['labels'].head(3)
# Out:
# 0    1
# 1    1
# 2    1
# Name: labels, dtype: int64

# %%
test_dict = {"x_col":test_x,
           "y_col":test_labels["labels"]}

# %%
len(test_x)
# Out:
# 1868

# %%
len(test_labels)
# Out:
# 1867

# %%
test_x=test_x.pop(0)

# %%
test_labels
# Out:
#                 Patient_ID new_names  labels
# 0      UID_57_29_1_all.bmp     1.bmp       1
# 1      UID_57_22_2_all.bmp     2.bmp       1
# 2      UID_57_31_3_all.bmp     3.bmp       1
# 3     UID_H49_35_1_hem.bmp     4.bmp       0
# 4      UID_58_6_13_all.bmp     5.bmp       1
# ...                    ...       ...     ...
# 1862   UID_54_33_1_all.bmp  1863.bmp       1
# 1863   UID_55_24_1_all.bmp  1864.bmp       1
# 1864  UID_H32_20_1_hem.bmp  1865.bmp       0
# 1865   UID_54_30_2_all.bmp  1866.bmp       1
# 1866   UID_66_10_3_all.bmp  1867.bmp       1
#
# [1867 rows x 3 columns]

# %%
test_df = pd.DataFrame(test_dict)
test_df["y_col"].replace(to_replace=[1,0],value=["ALL","HEM"],inplace=True)

# %%
test_data=r'/content/Project/PKG - C-NMC_Leukemia/C-NMC_Leukemia/C-NMC_test_final_phase_data'

# %%
test_x=get_path_image(test_data)

# %%
test_labels=test_labels['labels']

# %%
len(test_x)
# Out:
# 2586

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10661 entries, 0 to 10660
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x_col   10661 non-null  object
#  1   y_col   10661 non-null  object
# dtypes: object(2)
# memory usage: 166.7+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1867 entries, 0 to 1866
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x_col   1867 non-null   object
#  1   y_col   1867 non-null   object
# dtypes: object(2)
# memory usage: 29.3+ KB

# %% [markdown]
# # from tensorflow.keras.preprocessing.image import ImageDataGenerator:
#
# # 1. Generate batches of tensor image data with real-time data augmentation.
#
# # 2. Keras ImageDataGenerator is used for getting the input of the original data and further, it makes the transformation of this data on a random basis and gives the output resultant containing only the data that is newly transformed.
#
# # 3. It does not add the data. Keras image data generator class is also used to carry out data augmentation where we aim to gain the overall increment in the generalization of the model.
#
# # 4. Operations such as rotations, translations, shearin, scale changes, and horizontal flips are carried out randomly in data augmentation using an image data generator.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_gen = ImageDataGenerator()
test_gen = ImageDataGenerator()

train_generator = train_gen.flow_from_dataframe(
    train_df,
    x_col="x_col",
    y_col="y_col",
    target_size=(450, 450),
    batch_size=32,
    color_mode="rgb",
    shuffle=True,
    validation_split = 0.2,
    class_mode='binary')

test_generator = test_gen.flow_from_dataframe(
    test_df,
    x_col="x_col",
    y_col="y_col",
    target_size=(450, 450),
    batch_size=32,
    color_mode="rgb",
    shuffle=True,
    class_mode='binary')
# Out:
# Found 10661 validated image filenames belonging to 2 classes.
# Found 1866 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py:920: UserWarning: Found 1 invalid image filename(s) in x_col="x_col". These filename(s) will be ignored.
#   warnings.warn(

# %% [markdown]
# # Dense Layer is used to classify image based on output from convolutional layers.
#
# # Each Layer in the Neural Network contains neurons, which compute the weighted average of its input and this weighted average is passed through a non-linear function, called as an “activation function”.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D, Dropout, Flatten, BatchNormalization


model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(450, 450, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(450,450, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(169, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 448, 448, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 448, 448, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 446, 446, 32)        │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %% [markdown]
# #    Import the necessary libraries, including the test generator, the model, and any other relevant packages for data manipulation and visualization.
#
# #    Load the saved model weights, compile the model, and create the test generator using the appropriate settings for your data.
#
# #    Use the model's predict_generator() function to generate predictions for the test data.
#
# #    Use the flow_from_directory() function of the test generator to load the actual test images and their labels.
#
# #    Use a loop to iterate over a subset of the test images and their corresponding predicted labels.
#
# #    Use matplotlib or other data visualization tools to plot the actual and predicted images side by side.

# %%
# compile model
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# create test data generator
test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_gen.flow_from_dataframe(
    test_df,
    x_col="x_col",
    y_col="y_col",
    target_size=(450, 450),
    batch_size=32,
    color_mode="rgb",
    shuffle=True,
    class_mode='binary')

# generate predictions for test data
preds = model.predict(test_generator)

# load actual test images and labels
test_images, test_labels = next(test_generator)

#Since you are performing binary classification, you don't need argmax
# plot actual and predicted images
fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(10,10))

for i, ax in enumerate(axs.flat):
    ax.imshow(test_images[i])
    ax.set_title(f"Actual: {test_labels[i]},\nPredicted: {preds[i]}")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Found 1866 validated image filenames belonging to 2 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py:920: UserWarning: Found 1 invalid image filename(s) in x_col="x_col". These filename(s) will be ignored.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 36s 360ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# # In this code, we first generate predictions for the test data using the trained model.
#
# # Then, we load the actual test labels from the test generator.
#
# # We use scikit-learn's accuracy_score(), precision_recall_fscore_support(), and confusion_matrix() functions to calculate the accuracy, precision, recall, F1 score, and confusion matrix for the model's predictions.
#
# # Finally, we print these performance metrics using the print() function.

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_recall_fscore_support

# generate predictions for test data
preds = model.predict(test_generator)  # Use 'predict' instead of 'predict_generator'

# load actual test labels
test_labels = test_generator.classes

# ... rest of your code ...
# calculate performance metrics
accuracy = accuracy_score(test_labels, preds.argmax(axis=1))
precision, recall, f1_score, _ = precision_recall_fscore_support(test_labels, preds.argmax(axis=1), average='weighted')
confusion = confusion_matrix(test_labels, preds.argmax(axis=1))

# print performance metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
print("Confusion Matrix:")
print(confusion)
print("Classification Report:")
print(classification_report(test_labels, preds.argmax(axis=1), target_names=test_generator.class_indices.keys()))
# Out:
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step
# Accuracy: 0.6527
# Precision: 0.4261
# Recall: 0.6527
# F1 Score: 0.5156
# Confusion Matrix:
# [[1218    0]
#  [ 648    0]]
# Classification Report:
#               precision    recall  f1-score   support
#
#          ALL       0.65      1.00      0.79      1218
#          HEM       0.00      0.00      0.00       648
#
#     accuracy                           0.65      1866
#    macro avg       0.33      0.50      0.39      1866
# weighted avg       0.43      0.65      0.52      1866
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
import matplotlib.pyplot as plt

# set the validation split to 0.2
validation_split = 0.2

# fit the model and get the history object
history = model.fit(train_generator, epochs=10)#, validation_split=validation_split)

# plot the training and validation accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
#plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/losses/losses.py:27: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 230s 554ms/step - accuracy: 0.6791 - loss: 0.0000e+00
# Epoch 2/10
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 178s 528ms/step - accuracy: 0.6800 - loss: 0.0000e+00
# Epoch 3/10
# ...
