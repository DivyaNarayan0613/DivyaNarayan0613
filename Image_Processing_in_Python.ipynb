# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyaNarayan0613/DivyaNarayan0613/blob/main/Image_Processing_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg
# Out:
# --2022-10-15 09:25:08--  https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg
# Resolving iiif.lib.ncsu.edu (iiif.lib.ncsu.edu)... 152.14.136.80
# Connecting to iiif.lib.ncsu.edu (iiif.lib.ncsu.edu)|152.14.136.80|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 127143 (124K) [image/jpeg]
# Saving to: ‘default.jpg’
#
# default.jpg         100%[===================>] 124.16K   217KB/s    in 0.6s
#
# 2022-10-15 09:25:10 (217 KB/s) - ‘default.jpg’ saved [127143/127143]

# %%
from PIL import Image
import numpy as np
import os
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import cv2 
import random
from math import log
from google.colab.patches import cv2_imshow
from tqdm import tqdm

# %%
image="default"
ext=".jpg"

# %%
img = cv2.imread(image + ext)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x571 at 0x7FAD93052AD0>

# %%
img.shape
# Out:
# (571, 800, 3)

# %%
img1=cv2.resize(img,(200,200))

# %%
cv2.imwrite('resized_imaged.jpg', img1)
# Out:
# True

# %%
image="resized_imaged"
ext = ".jpg"
img = cv2.imread(image + ext)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FAD92F652D0>

# %%
image="default"
ext=".jpg"

# %%
img = cv2.imread(image + ext)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x571 at 0x7FAD92F78750>

# %%
edges = cv2.Canny(img,100,100)
plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
cropped_image = img[300:600, 400:900]
cv2.imwrite('cropped-image-opencv.jpg', cropped_image)
print(f"Cropped Image Dimensions : {cropped_image.shape}")
# Out:
# Cropped Image Dimensions : (271, 400, 3)

# %%
cv2_imshow(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x271 at 0x7FAD906978D0>

# %%
image=cv2.imread("default.jpg")
image_norm = cv2.normalize(image, None, alpha=0,beta=1000, norm_type=cv2.NORM_MINMAX)

# %%
cv2_imshow(image_norm)
# Out:
# <PIL.Image.Image image mode=RGB size=800x571 at 0x7FAD9065BB90>

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x571 at 0x7FAD906B6DD0>
